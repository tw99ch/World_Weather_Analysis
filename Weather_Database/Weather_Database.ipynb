# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d47aac7ea992677558cb21db7fce8e01

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 64.49,
#   'feels_like': 59.22,
#   'temp_min': 61,
#   'temp_max': 66.99,
#   'pressure': 1013,
#   'humidity': 68},
#  'visibility': 10000,
#  'wind': {'speed': 11.41, 'deg': 210},
#  'clouds': {'all': 40},
#  'dt': 1601600104,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1601548902,
#   'sunset': 1601591135},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather['weather'][0]['description']
                # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | paamiut
# Processing Record 2 of Set 15 | chifeng
# Processing Record 3 of Set 15 | bluff
# Processing Record 4 of Set 15 | bud
# Processing Record 5 of Set 15 | changde
# Processing Record 6 of Set 15 | arraial do cabo
# Processing Record 7 of Set 15 | carnarvon
# Processing Record 8 of Set 15 | jamestown
# Processing Record 9 of Set 15 | cape town
# Processing Record 10 of Set 15 | kapaa
# Processing Record 11 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 15 | komsomolskiy
# Processing Record 13 of Set 15 | bengkulu
# Processing Record 14 of Set 15 | cabo san lucas
# Processing Record 15 of Set 15 | namibe
# Processing Record 16 of Set 15 | la ronge
# Processing Record 17 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 15 | rikitea
# Processing Record 19 of Set 15 | lagoa
# Processing Record 20 of Set 15 | guerrero negro
# Processing Record 21 of Set 15 | beringovskiy
# Processing Record 22 of Set 15 | havre-saint-pierre
# Processing Record 23 of Set 15 | punta arenas
# Processing Record 24 of Set 15 | saint-pierre
# Processing Record 25 of Set 15 | norman wells
# Processing Record 26 of Set 15 | albany
# Processing Record 27 of Set 15 | weyburn
# Processing Record 28 of Set 15 | jieshi
# Processing Record 29 of Set 15 | ures
# Processing Record 30 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 15 | san rafael del sur
# Processing Record 32 of Set 15 | bilma
# Processing Record 33 of Set 15 | victoria
# Processing Record 34 of Set 15 | hilo
# Processing Record 35 of Set 15 | chuy
# Processing Record 36 of Set 15 | busselton
# Processing Record 37 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 15 | nanortalik
# Processing Record 39 of Set 15 | taoudenni
# Processing Record 40 of Set 15 | wyndham
# Processing Record 41 of Set 15 | qaanaaq
# Processing Record 42 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 15 | saint-francois
# Processing Record 45 of Set 15 | kamaishi
# Processing Record 46 of Set 15 | ilulissat
# Processing Record 47 of Set 15 | thompson
# Processing Record 48 of Set 15 | port alfred
# Processing Record 49 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 15 | fairbanks
# Processing Record 1 of Set 16 | ancud
# Processing Record 2 of Set 16 | mataura
# Processing Record 3 of Set 16 | adrar
# Processing Record 4 of Set 16 | monticello
# Processing Record 5 of Set 16 | comarnic
# Processing Record 6 of Set 16 | deputatskiy
# Processing Record 7 of Set 16 | tadine
# Processing Record 8 of Set 16 | angoche
# Processing Record 9 of Set 16 | soroti
# Processing Record 10 of Set 16 | boende
# Processing Record 11 of Set 16 | terrak
# Processing Record 12 of Set 16 | yuanping
# Processing Record 13 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 16 | parkes
# Processing Record 15 of Set 16 | skjervoy
# Processing Record 16 of Set 16 | alexander city
# Processing Record 17 of Set 16 | barrow
# Processing Record 18 of Set 16 | kholodnyy
# Processing Record 19 of Set 16 | tubuala
# Processing Record 20 of Set 16 | san patricio
# Processing Record 21 of Set 16 | brejo da madre de deus
# Processing Record 22 of Set 16 | hermanus
# Processing Record 23 of Set 16 | duz
# City not found. Skipping...
# Processing Record 24 of Set 16 | saldanha
# Processing Record 25 of Set 16 | esperance
# Processing Record 26 of Set 16 | mar del plata
# Processing Record 27 of Set 16 | pangkalanbuun
# Processing Record 28 of Set 16 | nikolskoye
# Processing Record 29 of Set 16 | atuona
# Processing Record 30 of Set 16 | uba
# Processing Record 31 of Set 16 | gari
# Processing Record 32 of Set 16 | cardenas
# Processing Record 33 of Set 16 | kahului
# Processing Record 34 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 16 | qaqortoq
# Processing Record 36 of Set 16 | selizharovo
# Processing Record 37 of Set 16 | port elizabeth
# Processing Record 38 of Set 16 | general roca
# Processing Record 39 of Set 16 | vardo
# Processing Record 40 of Set 16 | summerside
# Processing Record 41 of Set 16 | tuktoyaktuk
# Processing Record 42 of Set 16 | alofi
# Processing Record 43 of Set 16 | uzhhorod
# Processing Record 44 of Set 16 | hithadhoo
# Processing Record 45 of Set 16 | alta floresta
# Processing Record 46 of Set 16 | bethel
# Processing Record 47 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 16 | makueni
# Processing Record 49 of Set 16 | matara
# Processing Record 50 of Set 16 | new norfolk
# Processing Record 1 of Set 17 | chokurdakh
# Processing Record 2 of Set 17 | mogadishu
# Processing Record 3 of Set 17 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 17 | yellowknife
# Processing Record 5 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 17 | kavieng
# Processing Record 7 of Set 17 | tevaitoa
# Processing Record 8 of Set 17 | bilibino
# Processing Record 9 of Set 17 | bredasdorp
# Processing Record 10 of Set 17 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 17 | vaini
# Processing Record 12 of Set 17 | cayenne
# Processing Record 13 of Set 17 | mount gambier
# Processing Record 14 of Set 17 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 17 | verkhoyansk
# Processing Record 16 of Set 17 | katherine
# Processing Record 17 of Set 17 | harbour breton
# Processing Record 18 of Set 17 | ola
# Processing Record 19 of Set 17 | longyearbyen
# Processing Record 20 of Set 17 | artyk
# City not found. Skipping...
# Processing Record 21 of Set 17 | faro
# Processing Record 22 of Set 17 | puerto ayora
# Processing Record 23 of Set 17 | fortuna
# Processing Record 24 of Set 17 | ushuaia
# Processing Record 25 of Set 17 | sao filipe
# Processing Record 26 of Set 17 | almaznyy
# Processing Record 27 of Set 17 | grindavik
# Processing Record 28 of Set 17 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 17 | zhezkazgan
# Processing Record 30 of Set 17 | portland
# Processing Record 31 of Set 17 | lago da pedra
# Processing Record 32 of Set 17 | yanam
# Processing Record 33 of Set 17 | tiksi
# Processing Record 34 of Set 17 | xichang
# Processing Record 35 of Set 17 | cadiz
# Processing Record 36 of Set 17 | cidreira
# Processing Record 37 of Set 17 | lorengau
# Processing Record 38 of Set 17 | aleksandrovka
# Processing Record 39 of Set 17 | meulaboh
# Processing Record 40 of Set 17 | limon
# Processing Record 41 of Set 17 | hofn
# Processing Record 42 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 17 | dawei
# Processing Record 44 of Set 17 | souillac
# Processing Record 45 of Set 17 | punta cardon
# Processing Record 46 of Set 17 | sitka
# Processing Record 47 of Set 17 | camacha
# Processing Record 48 of Set 17 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 17 | nampula
# Processing Record 50 of Set 17 | saint-philippe
# Processing Record 1 of Set 18 | sahrak
# City not found. Skipping...
# Processing Record 2 of Set 18 | ponta do sol
# Processing Record 3 of Set 18 | butaritari
# Processing Record 4 of Set 18 | broken hill
# Processing Record 5 of Set 18 | ixmiquilpan
# Processing Record 6 of Set 18 | georgetown
# Processing Record 7 of Set 18 | formoso do araguaia
# City not found. Skipping...
# Processing Record 8 of Set 18 | wamba
# Processing Record 9 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 18 | hobart
# Processing Record 11 of Set 18 | san andres
# Processing Record 12 of Set 18 | udomlya
# Processing Record 13 of Set 18 | nome
# Processing Record 14 of Set 18 | omboue
# Processing Record 15 of Set 18 | torbay
# Processing Record 16 of Set 18 | kaitangata
# Processing Record 17 of Set 18 | severomuysk
# Processing Record 18 of Set 18 | mecca
# Processing Record 19 of Set 18 | severo-kurilsk
# Processing Record 20 of Set 18 | baruun-urt
# Processing Record 21 of Set 18 | kavaratti
# Processing Record 22 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 18 | luena
# Processing Record 24 of Set 18 | kupang
# Processing Record 25 of Set 18 | pevek
# Processing Record 26 of Set 18 | port hedland
# Processing Record 27 of Set 18 | muros
# Processing Record 28 of Set 18 | lompoc
# Processing Record 29 of Set 18 | malesina
# Processing Record 30 of Set 18 | byron bay
# Processing Record 31 of Set 18 | mosquera
# Processing Record 32 of Set 18 | jinchang
# Processing Record 33 of Set 18 | nantucket
# Processing Record 34 of Set 18 | umm lajj
# Processing Record 35 of Set 18 | kirakira
# Processing Record 36 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 18 | cascais
# Processing Record 38 of Set 18 | port macquarie
# Processing Record 39 of Set 18 | hasaki
# Processing Record 40 of Set 18 | lashio
# Processing Record 41 of Set 18 | faya
# Processing Record 42 of Set 18 | tuatapere
# Processing Record 43 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 18 | cap malheureux
# Processing Record 45 of Set 18 | krasnyy luch
# Processing Record 46 of Set 18 | nelson bay
# Processing Record 47 of Set 18 | ambon
# Processing Record 48 of Set 18 | moron
# Processing Record 49 of Set 18 | santa quiteria
# Processing Record 50 of Set 18 | faanui
# Processing Record 1 of Set 19 | vila velha
# Processing Record 2 of Set 19 | milkovo
# Processing Record 3 of Set 19 | fort-shevchenko
# Processing Record 4 of Set 19 | udachnyy
# Processing Record 5 of Set 19 | puerto escondido
# Processing Record 6 of Set 19 | bathsheba
# Processing Record 7 of Set 19 | rawson
# Processing Record 8 of Set 19 | port keats
# Processing Record 9 of Set 19 | charleston
# Processing Record 10 of Set 19 | north bend
# Processing Record 11 of Set 19 | verkh-chebula
# Processing Record 12 of Set 19 | ribeira grande
# Processing Record 13 of Set 19 | tanout
# Processing Record 14 of Set 19 | berlevag
# Processing Record 15 of Set 19 | yumen
# Processing Record 16 of Set 19 | gasa
# Processing Record 17 of Set 19 | kodiak
# Processing Record 18 of Set 19 | dikson
# Processing Record 19 of Set 19 | bouca
# Processing Record 20 of Set 19 | coquimbo
# Processing Record 21 of Set 19 | mount isa
# Processing Record 22 of Set 19 | suruc
# Processing Record 23 of Set 19 | muroto
# Processing Record 24 of Set 19 | teya
# Processing Record 25 of Set 19 | coolum beach
# Processing Record 26 of Set 19 | hirado
# Processing Record 27 of Set 19 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 19 | longhua
# Processing Record 29 of Set 19 | voyinka
# Processing Record 30 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 19 | nyzhni sirohozy
# Processing Record 32 of Set 19 | harper
# Processing Record 33 of Set 19 | shizunai
# Processing Record 34 of Set 19 | east london
# Processing Record 35 of Set 19 | gobabis
# Processing Record 36 of Set 19 | ahipara
# Processing Record 37 of Set 19 | tessalit
# Processing Record 38 of Set 19 | yulara
# Processing Record 39 of Set 19 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 19 | marsassoum
# Processing Record 41 of Set 19 | blonduos
# City not found. Skipping...
# Processing Record 42 of Set 19 | narsaq
# Processing Record 43 of Set 19 | boa vista
# Processing Record 44 of Set 19 | boffa
# Processing Record 45 of Set 19 | mitu
# Processing Record 46 of Set 19 | korla
# Processing Record 47 of Set 19 | khasan
# Processing Record 48 of Set 19 | clyde river
# Processing Record 49 of Set 19 | te anau
# Processing Record 50 of Set 19 | port blair
# Processing Record 1 of Set 20 | lira
# Processing Record 2 of Set 20 | corinto
# Processing Record 3 of Set 20 | mayo
# Processing Record 4 of Set 20 | nicoya
# Processing Record 5 of Set 20 | arman
# Processing Record 6 of Set 20 | singkawang
# Processing Record 7 of Set 20 | mokrousovo
# Processing Record 8 of Set 20 | yamethin
# Processing Record 9 of Set 20 | goroka
# Processing Record 10 of Set 20 | castro
# Processing Record 11 of Set 20 | chardara
# Processing Record 12 of Set 20 | butterworth
# Processing Record 13 of Set 20 | vao
# Processing Record 14 of Set 20 | talnakh
# Processing Record 15 of Set 20 | provideniya
# Processing Record 16 of Set 20 | pitimbu
# Processing Record 17 of Set 20 | ozernovskiy
# Processing Record 18 of Set 20 | mountain home
# Processing Record 19 of Set 20 | pitkyaranta
# Processing Record 20 of Set 20 | mto wa mbu
# Processing Record 21 of Set 20 | tyup
# Processing Record 22 of Set 20 | kushnarenkovo
# Processing Record 23 of Set 20 | leningradskiy
# Processing Record 24 of Set 20 | gat
# Processing Record 25 of Set 20 | iqaluit
# Processing Record 26 of Set 20 | upernavik
# Processing Record 27 of Set 20 | urumqi
# Processing Record 28 of Set 20 | okha
# Processing Record 29 of Set 20 | kaura namoda
# Processing Record 30 of Set 20 | asfi
# Processing Record 31 of Set 20 | airai
# Processing Record 32 of Set 20 | leh
# Processing Record 33 of Set 20 | lebu
# Processing Record 34 of Set 20 | hami
# Processing Record 35 of Set 20 | timizart
# Processing Record 36 of Set 20 | khatanga
# Processing Record 37 of Set 20 | jiayuguan
# Processing Record 38 of Set 20 | itarema
# Processing Record 39 of Set 20 | sindang
# Processing Record 40 of Set 20 | sambava
# Processing Record 41 of Set 20 | akureyri
# Processing Record 42 of Set 20 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 20 | mahebourg
# Processing Record 44 of Set 20 | touros
# Processing Record 45 of Set 20 | mashivka
# Processing Record 46 of Set 20 | kedougou
# Processing Record 47 of Set 20 | turukhansk
# Processing Record 48 of Set 20 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 20 | santa maria
# Processing Record 50 of Set 20 | togur
# Processing Record 1 of Set 21 | cockburn town
# Processing Record 2 of Set 21 | ansbach
# Processing Record 3 of Set 21 | shizuishan
# Processing Record 4 of Set 21 | saskylakh
# Processing Record 5 of Set 21 | bar harbor
# Processing Record 6 of Set 21 | venice
# Processing Record 7 of Set 21 | campos
# Processing Record 8 of Set 21 | padang
# Processing Record 9 of Set 21 | salalah
# Processing Record 10 of Set 21 | brae
# Processing Record 11 of Set 21 | totness
# Processing Record 12 of Set 21 | galiwinku
# City not found. Skipping...
# Processing Record 13 of Set 21 | bontang
# Processing Record 14 of Set 21 | puerto baquerizo moreno
# Processing Record 15 of Set 21 | mizoch
# Processing Record 16 of Set 21 | prince rupert
# Processing Record 17 of Set 21 | constitucion
# Processing Record 18 of Set 21 | ous
# Processing Record 19 of Set 21 | okhotsk
# Processing Record 20 of Set 21 | los llanos de aridane
# Processing Record 21 of Set 21 | sidi ali
# Processing Record 22 of Set 21 | bogovarovo
# Processing Record 23 of Set 21 | barra do garcas
# Processing Record 24 of Set 21 | marienburg
# Processing Record 25 of Set 21 | goderich
# Processing Record 26 of Set 21 | dhidhdhoo
# Processing Record 27 of Set 21 | talwara
# Processing Record 28 of Set 21 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 21 | gamba
# Processing Record 30 of Set 21 | moquegua
# Processing Record 31 of Set 21 | galt
# Processing Record 32 of Set 21 | rocha
# Processing Record 33 of Set 21 | soe
# Processing Record 34 of Set 21 | lavrentiya
# Processing Record 35 of Set 21 | we
# City not found. Skipping...
# Processing Record 36 of Set 21 | oksfjord
# Processing Record 37 of Set 21 | roald
# Processing Record 38 of Set 21 | aklavik
# Processing Record 39 of Set 21 | manokwari
# Processing Record 40 of Set 21 | xinglongshan
# Processing Record 41 of Set 21 | lima
# Processing Record 42 of Set 21 | coahuayana
# Processing Record 43 of Set 21 | palmer
# Processing Record 44 of Set 21 | sarangani
# Processing Record 45 of Set 21 | linqing
# Processing Record 46 of Set 21 | plainview
# Processing Record 47 of Set 21 | hambantota
# Processing Record 48 of Set 21 | tasiilaq
# Processing Record 49 of Set 21 | quatre cocos
# Processing Record 50 of Set 21 | comodoro rivadavia
# Processing Record 1 of Set 22 | peterhead
# Processing Record 2 of Set 22 | vestmannaeyjar
# Processing Record 3 of Set 22 | goulburn
# Processing Record 4 of Set 22 | yar-sale
# Processing Record 5 of Set 22 | beibei
# Processing Record 6 of Set 22 | xihe
# Processing Record 7 of Set 22 | winnemucca
# Processing Record 8 of Set 22 | klaksvik
# Processing Record 9 of Set 22 | lincoln
# Processing Record 10 of Set 22 | toungoo
# City not found. Skipping...
# Processing Record 11 of Set 22 | riyadh
# Processing Record 12 of Set 22 | kouroussa
# Processing Record 13 of Set 22 | ndele
# Processing Record 14 of Set 22 | port lincoln
# Processing Record 15 of Set 22 | acopiara
# Processing Record 16 of Set 22 | naze
# Processing Record 17 of Set 22 | arlit
# Processing Record 18 of Set 22 | bagotville
# Processing Record 19 of Set 22 | cherskiy
# Processing Record 20 of Set 22 | nemuro
# Processing Record 21 of Set 22 | san cristobal
# Processing Record 22 of Set 22 | shimoda
# Processing Record 23 of Set 22 | coari
# Processing Record 24 of Set 22 | ketchikan
# Processing Record 25 of Set 22 | kruisfontein
# Processing Record 26 of Set 22 | manaure
# Processing Record 27 of Set 22 | huarmey
# Processing Record 28 of Set 22 | toora-khem
# Processing Record 29 of Set 22 | dicabisagan
# Processing Record 30 of Set 22 | sorong
# Processing Record 31 of Set 22 | diffa
# Processing Record 32 of Set 22 | malanville
# Processing Record 33 of Set 22 | santa rosa
# Processing Record 34 of Set 22 | labuhan
# Processing Record 35 of Set 22 | avera
# Processing Record 36 of Set 22 | college
# Processing Record 37 of Set 22 | houma
# Processing Record 38 of Set 22 | sao joao da barra
# Processing Record 39 of Set 22 | fevik
# Processing Record 40 of Set 22 | yangjiang
# Processing Record 41 of Set 22 | valparaiso
# Processing Record 42 of Set 22 | mao
# Processing Record 43 of Set 22 | buraydah
# Processing Record 44 of Set 22 | maryville
# Processing Record 45 of Set 22 | de aar
# Processing Record 46 of Set 22 | lubango
# Processing Record 47 of Set 22 | channel-port aux basques
# Processing Record 48 of Set 22 | san mateo del mar
# Processing Record 49 of Set 22 | tianpeng
# Processing Record 50 of Set 22 | erzin
# Processing Record 1 of Set 23 | swadlincote
# Processing Record 2 of Set 23 | biloela
# Processing Record 3 of Set 23 | djambala
# Processing Record 4 of Set 23 | garissa
# Processing Record 5 of Set 23 | luanda
# Processing Record 6 of Set 23 | great yarmouth
# Processing Record 7 of Set 23 | abu samrah
# Processing Record 8 of Set 23 | benguela
# Processing Record 9 of Set 23 | rio verde de mato grosso
# Processing Record 10 of Set 23 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 23 | avarua
# Processing Record 12 of Set 23 | burnie
# Processing Record 13 of Set 23 | laguna
# Processing Record 14 of Set 23 | zhengjiatun
# Processing Record 15 of Set 23 | oia
# Processing Record 16 of Set 23 | kasra
# City not found. Skipping...
# Processing Record 17 of Set 23 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 23 | sainte-luce
# Processing Record 19 of Set 23 | kotelnikovo
# Processing Record 20 of Set 23 | batemans bay
# Processing Record 21 of Set 23 | luderitz
# Processing Record 22 of Set 23 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 23 | dawson creek
# Processing Record 24 of Set 23 | lubumbashi
# Processing Record 25 of Set 23 | kollam
# Processing Record 26 of Set 23 | cabedelo
# Processing Record 27 of Set 23 | maraa
# Processing Record 28 of Set 23 | oyama
# Processing Record 29 of Set 23 | koungou
# Processing Record 30 of Set 23 | nhulunbuy
# Processing Record 31 of Set 23 | borogontsy
# Processing Record 32 of Set 23 | areka
# Processing Record 33 of Set 23 | toccoa
# Processing Record 34 of Set 23 | douentza
# Processing Record 35 of Set 23 | springville
# Processing Record 36 of Set 23 | urcos
# Processing Record 37 of Set 23 | muli
# Processing Record 38 of Set 23 | krasnyy kut
# Processing Record 39 of Set 23 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 23 | marawi
# Processing Record 41 of Set 23 | zlobin
# Processing Record 42 of Set 23 | san isidro
# Processing Record 43 of Set 23 | praia
# Processing Record 44 of Set 23 | lesnica
# Processing Record 45 of Set 23 | healesville
# Processing Record 46 of Set 23 | solnechnyy
# Processing Record 47 of Set 23 | oytal
# Processing Record 48 of Set 23 | kloulklubed
# Processing Record 49 of Set 23 | cubarral
# Processing Record 50 of Set 23 | honningsvag
# Processing Record 1 of Set 24 | octeville
# Processing Record 2 of Set 24 | karratha
# Processing Record 3 of Set 24 | heinola
# Processing Record 4 of Set 24 | kushiro
# Processing Record 5 of Set 24 | russell
# Processing Record 6 of Set 24 | srednekolymsk
# Processing Record 7 of Set 24 | kijang
# Processing Record 8 of Set 24 | pangoa
# Processing Record 9 of Set 24 | maragogi
# Processing Record 10 of Set 24 | jiangyou
# Processing Record 11 of Set 24 | lethem
# Processing Record 12 of Set 24 | birao
# Processing Record 13 of Set 24 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 24 | pangnirtung
# Processing Record 15 of Set 24 | bambous virieux
# Processing Record 16 of Set 24 | azare
# Processing Record 17 of Set 24 | ulladulla
# Processing Record 18 of Set 24 | pleszew
# Processing Record 19 of Set 24 | anadyr
# Processing Record 20 of Set 24 | ugoofaaru
# Processing Record 21 of Set 24 | baghdad
# Processing Record 22 of Set 24 | juneau
# Processing Record 23 of Set 24 | ostrovnoy
# Processing Record 24 of Set 24 | danville
# Processing Record 25 of Set 24 | port pirie
# Processing Record 26 of Set 24 | srikakulam
# Processing Record 27 of Set 24 | colares
# Processing Record 28 of Set 24 | san rafael
# Processing Record 29 of Set 24 | bagan
# Processing Record 30 of Set 24 | hirara
# Processing Record 31 of Set 24 | sangar
# Processing Record 32 of Set 24 | guane
# Processing Record 33 of Set 24 | tucuman
# Processing Record 34 of Set 24 | pinega
# Processing Record 35 of Set 24 | abha
# Processing Record 36 of Set 24 | margate
# Processing Record 37 of Set 24 | olinda
# Processing Record 38 of Set 24 | sibolga
# Processing Record 39 of Set 24 | sinnamary
# Processing Record 40 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 24 | bosaso
# Processing Record 42 of Set 24 | mandurah
# Processing Record 43 of Set 24 | severobaykalsk
# Processing Record 44 of Set 24 | codrington
# Processing Record 45 of Set 24 | oranjemund
# Processing Record 46 of Set 24 | whitehorse
# Processing Record 47 of Set 24 | grand-lahou
# Processing Record 48 of Set 24 | port hardy
# Processing Record 49 of Set 24 | kirkland lake
# Processing Record 50 of Set 24 | kenai
# Processing Record 1 of Set 25 | walvis bay
# Processing Record 2 of Set 25 | jijiga
# Processing Record 3 of Set 25 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 25 | bol
# Processing Record 5 of Set 25 | cotonou
# Processing Record 6 of Set 25 | ronneby
# Processing Record 7 of Set 25 | hokitika
# Processing Record 8 of Set 25 | eldorado
# Processing Record 9 of Set 25 | kamenka
# Processing Record 10 of Set 25 | uchiza
# Processing Record 11 of Set 25 | daru
# Processing Record 12 of Set 25 | vila do maio
# Processing Record 13 of Set 25 | reidsville
# Processing Record 14 of Set 25 | bowen
# Processing Record 15 of Set 25 | lafia
# Processing Record 16 of Set 25 | wajima
# Processing Record 17 of Set 25 | aguimes
# Processing Record 18 of Set 25 | waipawa
# Processing Record 19 of Set 25 | mattawa
# Processing Record 20 of Set 25 | katsuura
# Processing Record 21 of Set 25 | zhangjiakou
# Processing Record 22 of Set 25 | blenheim
# Processing Record 23 of Set 25 | khatassy
# Processing Record 24 of Set 25 | hay river
# Processing Record 25 of Set 25 | belmonte
# Processing Record 26 of Set 25 | mbekenyera
# Processing Record 27 of Set 25 | bergama
# Processing Record 28 of Set 25 | calvinia
# Processing Record 29 of Set 25 | mahon
# Processing Record 30 of Set 25 | qorveh
# Processing Record 31 of Set 25 | road town
# Processing Record 32 of Set 25 | alice springs
# Processing Record 33 of Set 25 | axim
# Processing Record 34 of Set 25 | avanigadda
# Processing Record 35 of Set 25 | porto murtinho
# Processing Record 36 of Set 25 | ucluelet
# Processing Record 37 of Set 25 | erenhot
# Processing Record 38 of Set 25 | athabasca
# Processing Record 39 of Set 25 | elko
# Processing Record 40 of Set 25 | vestmanna
# Processing Record 41 of Set 25 | mackay
# Processing Record 42 of Set 25 | chilca
# Processing Record 43 of Set 25 | bandarbeyla
# Processing Record 44 of Set 25 | mastic beach
# Processing Record 45 of Set 25 | macamic
# Processing Record 46 of Set 25 | bargi
# Processing Record 47 of Set 25 | beni
# Processing Record 48 of Set 25 | bundaberg
# Processing Record 49 of Set 25 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 25 | marabella
# Processing Record 1 of Set 26 | vila franca do campo
# Processing Record 2 of Set 26 | kashi
# Processing Record 3 of Set 26 | catamarca
# Processing Record 4 of Set 26 | temiscaming
# Processing Record 5 of Set 26 | xinan
# Processing Record 6 of Set 26 | necochea
# Processing Record 7 of Set 26 | peniche
# Processing Record 8 of Set 26 | waingapu
# Processing Record 9 of Set 26 | husavik
# Processing Record 10 of Set 26 | mandalgovi
# Processing Record 11 of Set 26 | saint-augustin
# Processing Record 12 of Set 26 | trujillo
# Processing Record 13 of Set 26 | biltine
# Processing Record 14 of Set 26 | midyat
# Processing Record 15 of Set 26 | bogo
# Processing Record 16 of Set 26 | palanga
# Processing Record 17 of Set 26 | bolivar
# Processing Record 18 of Set 26 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 26 | lianzhou
# Processing Record 20 of Set 26 | lages
# Processing Record 21 of Set 26 | dinguiraye
# Processing Record 22 of Set 26 | izhma
# Processing Record 23 of Set 26 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 26 | ventspils
# Processing Record 25 of Set 26 | caramay
# Processing Record 26 of Set 26 | santander
# Processing Record 27 of Set 26 | isangel
# Processing Record 28 of Set 26 | mabaruma
# Processing Record 29 of Set 26 | sandpoint
# Processing Record 30 of Set 26 | itacoatiara
# Processing Record 31 of Set 26 | norrtalje
# Processing Record 32 of Set 26 | dunedin
# Processing Record 33 of Set 26 | skibbereen
# Processing Record 34 of Set 26 | suntar
# Processing Record 35 of Set 26 | fremont
# Processing Record 36 of Set 26 | gomel
# Processing Record 37 of Set 26 | belaya gora
# Processing Record 38 of Set 26 | hovd
# Processing Record 39 of Set 26 | amahai
# Processing Record 40 of Set 26 | zaysan
# Processing Record 41 of Set 26 | bubaque
# Processing Record 42 of Set 26 | kathmandu
# Processing Record 43 of Set 26 | fort nelson
# Processing Record 44 of Set 26 | bosanska gradiska
# Processing Record 45 of Set 26 | seoul
# Processing Record 46 of Set 26 | sumbe
# Processing Record 47 of Set 26 | chumikan
# Processing Record 48 of Set 26 | kutum
# Processing Record 49 of Set 26 | parvatsar
# Processing Record 50 of Set 26 | nouadhibou
# Processing Record 1 of Set 27 | rajura
# Processing Record 2 of Set 27 | vuktyl
# Processing Record 3 of Set 27 | tuy hoa
# Processing Record 4 of Set 27 | chapais
# Processing Record 5 of Set 27 | kungurtug
# Processing Record 6 of Set 27 | sayyan
# Processing Record 7 of Set 27 | namanga
# Processing Record 8 of Set 27 | saint george
# Processing Record 9 of Set 27 | mozhga
# Processing Record 10 of Set 27 | dubenskiy
# City not found. Skipping...
# Processing Record 11 of Set 27 | binzhou
# Processing Record 12 of Set 27 | parfino
# Processing Record 13 of Set 27 | kuching
# Processing Record 14 of Set 27 | nueva loja
# Processing Record 15 of Set 27 | kailua
# Processing Record 16 of Set 27 | high level
# Processing Record 17 of Set 27 | tiznit
# Processing Record 18 of Set 27 | bambanglipuro
# Processing Record 19 of Set 27 | pauini
# Processing Record 20 of Set 27 | rovenki
# Processing Record 21 of Set 27 | manzanillo
# Processing Record 22 of Set 27 | rundu
# Processing Record 23 of Set 27 | banjar
# Processing Record 24 of Set 27 | marondera
# Processing Record 25 of Set 27 | kaili
# Processing Record 26 of Set 27 | batticaloa
# Processing Record 27 of Set 27 | pedasi
# Processing Record 28 of Set 27 | hamilton
# Processing Record 29 of Set 27 | vallenar
# Processing Record 30 of Set 27 | havre
# Processing Record 31 of Set 27 | pisco
# Processing Record 32 of Set 27 | kondinskoye
# Processing Record 33 of Set 27 | verkhnevilyuysk
# Processing Record 34 of Set 27 | barabai
# Processing Record 35 of Set 27 | zychlin
# Processing Record 36 of Set 27 | rumonge
# Processing Record 37 of Set 27 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 27 | tineo
# Processing Record 39 of Set 27 | poopo
# Processing Record 40 of Set 27 | mizdah
# Processing Record 41 of Set 27 | pafos
# Processing Record 42 of Set 27 | tulcingo
# City not found. Skipping...
# Processing Record 43 of Set 27 | jurado
# Processing Record 44 of Set 27 | warrenton
# Processing Record 45 of Set 27 | panevezys
# Processing Record 46 of Set 27 | geraldton
# Processing Record 47 of Set 27 | tautira
# Processing Record 48 of Set 27 | uvalde
# Processing Record 49 of Set 27 | amsterdam
# Processing Record 50 of Set 27 | christchurch
# Processing Record 1 of Set 28 | havelock
# Processing Record 2 of Set 28 | taksimo
# Processing Record 3 of Set 28 | xining
# Processing Record 4 of Set 28 | impfondo
# Processing Record 5 of Set 28 | san javier
# Processing Record 6 of Set 28 | livingston
# Processing Record 7 of Set 28 | gravdal
# Processing Record 8 of Set 28 | prieska
# Processing Record 9 of Set 28 | balkhash
# Processing Record 10 of Set 28 | caxito
# Processing Record 11 of Set 28 | san juan
# Processing Record 12 of Set 28 | dingzhou
# Processing Record 13 of Set 28 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 28 | san luis
# Processing Record 15 of Set 28 | dalvik
# Processing Record 16 of Set 28 | iranshahr
# Processing Record 17 of Set 28 | qiqihar
# Processing Record 18 of Set 28 | clearwater
# Processing Record 19 of Set 28 | martapura
# Processing Record 20 of Set 28 | stolin
# Processing Record 21 of Set 28 | zaraza
# Processing Record 22 of Set 28 | pinheiro
# Processing Record 23 of Set 28 | mitsamiouli
# Processing Record 24 of Set 28 | dingle
# Processing Record 25 of Set 28 | malaya purga
# Processing Record 26 of Set 28 | wanning
# Processing Record 27 of Set 28 | zhigansk
# Processing Record 28 of Set 28 | hammerfest
# Processing Record 29 of Set 28 | katsiveli
# City not found. Skipping...
# Processing Record 30 of Set 28 | pajan
# Processing Record 31 of Set 28 | nago
# Processing Record 32 of Set 28 | wanxian
# Processing Record 33 of Set 28 | bulgan
# Processing Record 34 of Set 28 | batagay-alyta
# Processing Record 35 of Set 28 | storslett
# Processing Record 36 of Set 28 | picota
# Processing Record 37 of Set 28 | tobermory
# Processing Record 38 of Set 28 | tahta
# Processing Record 39 of Set 28 | zolotinka
# City not found. Skipping...
# Processing Record 40 of Set 28 | puerto ayacucho
# Processing Record 41 of Set 28 | mirnyy
# Processing Record 42 of Set 28 | makakilo city
# Processing Record 43 of Set 28 | mnogovershinnyy
# Processing Record 44 of Set 28 | bitung
# Processing Record 45 of Set 28 | madang
# Processing Record 46 of Set 28 | san carlos de bariloche
# Processing Record 47 of Set 28 | upata
# Processing Record 48 of Set 28 | uvarovka
# Processing Record 49 of Set 28 | bad salzungen
# Processing Record 50 of Set 28 | evensk
# Processing Record 1 of Set 29 | namatanai
# Processing Record 2 of Set 29 | hermosillo
# Processing Record 3 of Set 29 | caborca
# Processing Record 4 of Set 29 | inhumas
# Processing Record 5 of Set 29 | kozhva
# Processing Record 6 of Set 29 | sydney mines
# Processing Record 7 of Set 29 | lasa
# Processing Record 8 of Set 29 | hobyo
# Processing Record 9 of Set 29 | aleksandrov gay
# Processing Record 10 of Set 29 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 29 | alexandria
# Processing Record 12 of Set 29 | puerto leguizamo
# Processing Record 13 of Set 29 | olafsvik
# Processing Record 14 of Set 29 | mehamn
# Processing Record 15 of Set 29 | lacombe
# Processing Record 16 of Set 29 | marpingen
# Processing Record 17 of Set 29 | edgewater
# Processing Record 18 of Set 29 | beyneu
# Processing Record 19 of Set 29 | weihe
# Processing Record 20 of Set 29 | zaton
# Processing Record 21 of Set 29 | tiarei
# Processing Record 22 of Set 29 | bo
# City not found. Skipping...
# Processing Record 23 of Set 29 | shimanovsk
# Processing Record 24 of Set 29 | kualakapuas
# Processing Record 25 of Set 29 | padilla
# Processing Record 26 of Set 29 | qinzhou
# Processing Record 27 of Set 29 | shahrud
# Processing Record 28 of Set 29 | simao
# Processing Record 29 of Set 29 | ilhabela
# Processing Record 30 of Set 29 | karamea
# City not found. Skipping...
# Processing Record 31 of Set 29 | senneterre
# Processing Record 32 of Set 29 | mbalmayo
# Processing Record 33 of Set 29 | lahij
# Processing Record 34 of Set 29 | nuuk
# Processing Record 35 of Set 29 | kristiansund
# Processing Record 36 of Set 29 | rio grande
# Processing Record 37 of Set 29 | castelo
# Processing Record 38 of Set 29 | kaberamaido
# Processing Record 39 of Set 29 | biankouma
# Processing Record 40 of Set 29 | nokaneng
# Processing Record 41 of Set 29 | mitikas
# Processing Record 42 of Set 29 | natal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Paamiut      GL  61.99  -49.67     37.89        92         100
# 1          Chifeng      CN  42.27  118.96     52.47        44           0
# 2            Bluff      NZ -46.60  168.33     57.00        57         100
# 3              Bud      US  39.45  -86.18     54.00        62          75
# 4          Changde      CN  29.05  111.68     71.06        91          94
# 5  Arraial Do Cabo      BR -22.97  -42.03     74.46        85           0
# 6        Carnarvon      AU -24.87  113.63     68.00        68          75
# 7        Jamestown      US  42.10  -79.24     48.99        87          90
# 8        Cape Town      ZA -33.93   18.42     57.99        58          20
# 9            Kapaa      US  22.08 -159.32     86.00        62           1
#
#    Wind Speed Current Description
# 0       58.54       moderate rain
# 1       19.19           clear sky
# 2       11.01          light rain
# 3        8.05       broken clouds
# 4        4.99     overcast clouds
# 5       25.79           clear sky
# 6       11.41       broken clouds
# 7        5.82     overcast clouds
# 8       24.16          few clouds
# 9        9.17           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
